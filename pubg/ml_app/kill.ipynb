# %%
from chicken_dinner.pubgapi import PUBG
api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJmZThiOWIyMC05ZDRhLTAxM2EtYzQ3Yi0wZTVmZGQ2ODc3NTYiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjQ5ODQ5NDA3LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InB1YmdfYXBpX3Byb2plIn0.jwbNcForczhmcOWRdeBqSY5NlrE9yTErGmTycPHUzNw"

# %%
def kill(platform,match_id,erangel,miramar,taego):
    pubg = PUBG(api_key=api_key, shard=f"{platform}")
    match = pubg.match(f"{match_id}")
    telemetry = match.get_telemetry()
    if telemetry.map_name() == "Erangel":
        kill_events = telemetry.filter_by("log_player_kill_v2")
        for kill in kill_events:
            killer_dmg = kill.killer_damage_info
            erangel.append(killer_dmg)
    elif telemetry.map_name() == "Miramar":
        kill_events = telemetry.filter_by("log_player_kill_v2")
        for kill in kill_events:
            killer_dmg = kill.killer_damage_info
            miramar.append(killer_dmg)
    elif telemetry.map_name() == "Taego":
        kill_events = telemetry.filter_by("log_player_kill_v2")
        for kill in kill_events:
            killer_dmg = kill.killer_damage_info
            taego.append(killer_dmg)
    else:
        print(telemetry.map_name())
        pass

# %%
steam_erangel = []
steam_miramar = []
steam_taego = []

# %%
kill("steam",'4831f5a1-f877-4297-ac76-51f9c6f6281d',steam_erangel,steam_miramar,steam_taego)

# %%
steam_miramar
# Out:
# [TelemetryObject({
#      "additional_info": [],
#      "damage_causer_name": "",
#      "damage_reason": "",
#      "damage_type_category": "",
#      "distance": -1,
#      "is_through_penetrable_wall": false
#  }, killer_damage_info),
#  TelemetryObject({
#      "additional_info": [],
#      "damage_causer_name": "ProjGrenade_C",
#      "damage_reason": "NonSpecific",
#      "damage_type_category": "Damage_Explosion_Grenade",
#      "distance": 1903.7030029296875,
#      "is_through_penetrable_wall": false
#  }, killer_damage_info),
#  TelemetryObject({
#      "additional_info": [],
#      "damage_causer_name": "",
#      "damage_reason": "",
#      "damage_type_category": "",
#      "distance": -1,
#      "is_through_penetrable_wall": false
#  }, killer_damage_info),
#  TelemetryObject({
#      "additional_info": [
#          "Item_Attach_Weapon_Lower_HalfGrip_C"
#      ],
#      "damage_causer_name": "WeapHK416_C",
#      "damage_reason": "TorsoShot",
# ...

# %%
pubg = PUBG(api_key=api_key, shard=f"steam")
match = pubg.match('9ee17d16-3a85-4510-8126-279f7ee9e1a8')
telemetry = match.get_telemetry()

# %%
#kill_events = telemetry.filter_by("log_player_kill_v2")

# %%
#rank_list = {'account.a2aac865133f4f658a88f1de91c215f5': 2, 'account.96ffd52ac0884607b1fa381a4a34e96c': 8, 'account.28eaaa92ee7d42139269c65e0076ff35': 3, 'account.b1b0b6ec396f49729353ba46568a02e6': 6, 'account.bb3d184a812a4ff988121bc9021b0255': 12, 'account.fe969891f1434e4ebbe7e82997029e45': 10, 'account.b53bbec3dca3470f95984b4834507696': 14, 'account.cb5902baeef14ed9a2e7ab59b44b3d0f': 13, 'account.2885adda1bd84881a475a88c49b86822': 5, 'account.43962d658b464977ad6f91026b0901b1': 7, 'account.f1d0d0849c22476eb78d9d6672355e75': 4, 'account.97a600d640e6483d8e79792c91a61098': 9, 'account.6f7e1f5b946e428e913cce0b5ac71032': 11, 'account.fa00481216a546f2b64bb2490dff39ac': 16, 'account.dc01dcd3b8fc4c80bae3e5b3c0e72c47': 1, 'account.a738270f2df84a588a74398750bec711': 15}

# %%
#kill_events[0]['killer']["account_id"]
# Out:
# 'account.9cc5ca8e61e947ababd63f3b2bec58ec'

# %%
match.map_name
# Out:
# 'Erangel (Remastered)'

# %%
rosters = match.rosters
rosters

# %%
roster = rosters[0]

# %%
roster_participants = roster.participants

# %%
roster_participants

# %%
rosters = match.rosters
rank_list = {}
for roster in rosters:
    rank_list[roster.player_ids[0]] = roster.stats['rank']
    for participant in roster.participants:
        rank_list[participant.player_id[0]] = roster.stats['rank']

# %%
rank_list
# Out:
# {'account.a2aac865133f4f658a88f1de91c215f5': 1,
#  'a': 4,
#  'account.11813c96a546488299699c660baa7648': 8,
#  'account.5a25e2e97afb4406a42ebf0c3edb8fc0': 5,
#  'account.d20c5a708c4043959eb0e115be27062d': 10,
#  'account.12a594ae2118492ba6547a4fa04410ba': 16,
#  'account.8df4560bec71484995ce9c7aa40c93eb': 7,
#  'account.88a61f8c73f244b486023a94ef0ada26': 11,
#  'account.b6efe92d2dab4ac9b8b3e1ba57f44e7e': 14,
#  'account.e319fa430ddb4d7e863b834249386f53': 3,
#  'account.5530ad757fc0427aa9dba6c79a4ff026': 2,
#  'account.ba48dbb54ea64eb5b4830d5375d8538c': 13,
#  'account.c867fa685c5c4d6d93e71a5b4bbf9bc5': 15,
#  'account.f8edbf5b454f4a429efa9724be424500': 9,
#  'account.b00127799ccf488aabe1a7eb189d8c14': 6,
#  'account.aec6e57b64eb4ae2b32d894ee5a0590d': 12,
#  'account.991c148f4517428e9833aeb5293d1e79': 4}
